# %% [markdown]
# # Arithmetic Operations in Pandas

# %% [markdown]
# Hi Guys, Welcome to [Tirendaz Academy](https://youtube.com/c/tirendazacademy) 😀
# </br>
# In this notebook, I'm going to show arithmetic operations in Pandas.
# </br>
# Happy Learning 🐱‍🏍

# %%
import pandas as pd
import numpy as np

# %%
s1=pd.Series(np.arange(4),
             index=["a","c","d","e"])
s2=pd.Series(np.arange(5),
             index=["a","c","e","f","g"])

# %%
print(s1)
print(s2)
# Out:
# a    0
# c    1
# d    2
# e    3
# dtype: int64
# a    0
# c    1
# e    2
# f    3
# g    4
# dtype: int64

# %%
s1+s2
# Out:
# a    0.0
# c    2.0
# d    NaN
# e    5.0
# f    NaN
# g    NaN
# dtype: float64

# %%
df1=pd.DataFrame(
    np.arange(6).reshape(2,3),
    columns=list("ABC"),
    index=["Tim","Tom"])
df2=pd.DataFrame(
    np.arange(9).reshape(3,3),
    columns=list("ACD"),
    index=["Tim","Kate","Tom"])

# %%
print(df1)
print(df2)
# Out:
#      A  B  C
# Tim  0  1  2
# Tom  3  4  5
#       A  C  D
# Tim   0  1  2
# Kate  3  4  5
# Tom   6  7  8

# %%
df1+df2
# Out:
#         A   B     C   D
# Kate  NaN NaN   NaN NaN
# Tim   0.0 NaN   3.0 NaN
# Tom   9.0 NaN  12.0 NaN

# %%
df2.add(df1,fill_value=0)
# Out:
#         A    B     C    D
# Kate  3.0  NaN   4.0  5.0
# Tim   0.0  1.0   3.0  2.0
# Tom   9.0  4.0  12.0  8.0

# %%
1/df1
# Out:
#             A     B    C
# Tim       inf  1.00  0.5
# Tom  0.333333  0.25  0.2

# %%
df1*3
# Out:
#      A   B   C
# Tim  0   3   6
# Tom  9  12  15

# %%
df1.mul(3)
# Out:
#      A  B  C
# Tim -3 -2 -1
# Tom  0  1  2

# %%
df2
# Out:
#       A  C  D
# Tim   0  1  2
# Kate  3  4  5
# Tom   6  7  8

# %%
s=df2.iloc[1]
s
# Out:
# A    3
# C    4
# D    5
# Name: Kate, dtype: int64

# %%
df2.loc["Kate"]
# Out:
# A    3
# C    4
# D    5
# Name: Kate, dtype: int64

# %%
df2
# Out:
#       A  C  D
# Tim   0  1  2
# Kate  3  4  5
# Tom   6  7  8

# %%
s
# Out:
# A    3
# C    4
# D    5
# Name: Kate, dtype: int64

# %%
df2-s
# Out:
#       A  C  D
# Tim  -3 -3 -3
# Kate  0  0  0
# Tom   3  3  3

# %%
s2=df2["A"];
s2
# Out:
# Tim     0
# Kate    3
# Tom     6
# Name: A, dtype: int64

# %%
df2.sub(s2,axis="index")
# Out:
#       A  C  D
# Tim   0  1  2
# Kate  0  1  2
# Tom   0  1  2

# %% [markdown]
# ## Applying a Function

# %%
df=pd.DataFrame(
    np.random.randn(4,3),
    columns=list("ABC"),
    index=["Kim","Susan","Tim","Tom"])
df
# Out:
#               A         B         C
# Kim    1.534827  0.301943 -0.588253
# Susan -0.140850  0.316698  1.407662
# Tim    1.574075 -1.418657 -0.890152
# Tom    1.024974 -0.460992  2.158399

# %%
np.abs(df)
# Out:
#               A         B         C
# Kim    1.982552  2.005781  1.233413
# Susan  1.097045  0.389652  0.361900
# Tim    1.467917  0.442251  0.805558
# Tom    0.495226  0.994970  1.547956

# %%
df
# Out:
#               A         B         C
# Kim   -1.982552  2.005781  1.233413
# Susan  1.097045 -0.389652  0.361900
# Tim   -1.467917  0.442251 -0.805558
# Tom   -0.495226 -0.994970  1.547956

# %%
f=lambda x:x.max()-x.min()

# %%
df.apply(f,axis=0)
# Out:
# A    3.079597
# B    3.000751
# C    2.353515
# dtype: float64

# %%
df.apply(f,axis=1)
# Out:
# Kim      0.823838
# Susan    2.717321
# Tim      2.091114
# Tom      0.879753
# dtype: float64

# %%
def f(x):
    return x**2

# %%
df.iloc[0].apply(f)
# Out:
# A    2.355693
# B    0.091170
# C    0.346042
# Name: Kim, dtype: float64

# %%
df
# Out:
#               A         B         C
# Kim    1.534827  0.301943 -0.588253
# Susan -0.140850  0.316698  1.407662
# Tim    1.574075 -1.418657 -0.890152
# Tom    1.024974 -0.460992  2.158399

# %% [markdown]
# Don't forget to follow us on [YouTube](http://youtube.com/tirendazacademy) | [Medium](http://tirendazacademy.medium.com) | [Twitter](http://twitter.com/tirendazacademy) | [GitHub](http://github.com/tirendazacademy) | [Linkedin](https://www.linkedin.com/in/tirendaz-academy) | [Kaggle](https://www.kaggle.com/tirendazacademy) 😎
